# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/brain-tumor-mri-scans/pituitary/0664.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1269.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0733.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0106.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0375.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1700.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1075.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0285.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0591.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0799.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1411.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0074.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1031.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0077.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0498.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1749.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0610.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1501.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1385.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0617.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1383.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1354.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1024.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0426.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1626.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0989.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0235.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0273.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0307.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1711.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0444.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1339.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0058.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0748.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0255.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1161.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1380.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1009.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0128.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1157.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1304.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1340.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1173.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1650.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1211.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0700.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1488.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0364.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1167.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1644.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1539.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1355.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0798.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0246.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1565.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1409.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1222.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1154.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0337.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0208.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0680.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0834.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0861.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1124.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1395.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0141.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1459.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0742.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0781.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0474.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0372.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1055.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0933.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0970.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0327.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1548.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0932.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1715.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0053.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1026.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0165.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0355.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0520.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1162.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0203.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0006.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0543.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0705.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0095.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1484.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0959.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1702.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1010.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1451.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1025.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1343.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1579.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0801.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0070.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0436.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0155.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0710.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0559.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0092.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1473.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0057.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0450.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1669.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0699.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0814.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0240.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1746.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0044.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0862.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1058.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0078.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1498.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1166.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1601.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1443.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0091.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0533.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0506.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0011.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1559.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1101.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0714.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0654.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1327.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0404.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1097.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0171.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1376.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0841.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0410.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0871.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0622.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0184.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1297.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1478.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1413.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1604.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0056.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0019.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1129.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0008.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1655.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0934.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1144.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0318.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1716.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0154.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0429.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1032.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1709.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0116.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0647.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0958.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0917.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1125.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1331.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0061.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0879.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0431.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0875.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1424.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0082.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1037.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0817.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1089.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0663.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1136.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1171.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1387.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1744.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1391.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0856.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1134.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1389.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1475.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0207.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0626.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1554.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1243.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1499.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0178.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0107.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1002.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1172.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0887.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0067.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1527.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0027.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0883.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0548.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0888.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0755.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1401.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0502.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1041.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1196.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0076.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0098.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1312.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1648.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0175.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0901.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1071.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1575.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1336.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0403.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0727.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0963.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1569.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1680.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0331.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1019.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0026.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0021.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0181.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0145.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1727.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0991.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0252.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0729.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0791.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0674.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1371.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1168.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1677.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0882.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1076.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1183.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0542.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0601.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1268.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0943.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1603.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0302.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0065.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0899.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0564.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1660.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1755.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1118.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0500.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1592.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1108.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1571.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0573.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0773.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1018.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0140.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0952.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0808.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0079.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0271.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0005.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0581.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0042.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0490.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1078.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0405.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0599.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0323.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0433.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1241.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0000.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1191.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1295.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0794.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1366.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0684.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0415.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0040.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0094.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0289.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0387.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1067.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1359.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0859.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0661.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0132.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0819.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0594.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1200.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1330.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0541.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0380.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0386.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0369.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0857.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1706.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0648.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0439.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1688.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1584.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1288.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0247.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1708.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1123.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0646.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0577.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1310.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1738.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1197.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0423.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0475.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0555.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0653.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1094.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0517.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0889.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1080.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0424.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1235.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0226.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0282.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0886.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0009.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0762.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1160.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0432.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0438.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1318.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0956.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0023.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1206.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0787.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0596.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0706.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1549.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1091.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1580.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0046.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1710.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1551.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1012.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1471.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0535.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0927.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0527.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0320.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0688.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0583.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1582.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0826.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1629.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0921.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0849.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0279.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0789.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0146.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1328.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1034.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0768.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1048.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1562.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1673.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0237.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0268.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0973.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1084.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1634.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0377.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0694.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0780.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0292.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1289.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1146.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1095.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1329.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0922.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0579.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0055.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0532.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0238.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1534.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1665.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0611.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1440.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0290.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1044.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1748.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1496.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0558.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0031.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1737.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0093.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0214.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1735.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0454.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1434.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0169.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1099.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1082.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0900.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0990.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0495.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0402.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0775.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0967.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1054.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1017.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0421.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1406.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0672.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1649.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0068.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1372.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0228.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0110.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1733.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0032.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1544.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1324.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0805.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0812.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0300.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0987.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0195.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1563.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0478.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0261.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0537.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0277.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1607.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1523.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1625.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0457.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1259.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0997.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0721.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1547.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0954.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0823.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1557.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0455.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0370.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0650.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0135.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0863.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0831.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0136.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0350.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0111.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0188.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1060.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1126.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0590.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1642.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0585.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0931.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0999.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1718.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0708.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0994.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1494.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1378.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0193.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0351.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0345.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1511.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1507.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0440.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1315.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1503.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1274.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1287.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0315.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0376.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0597.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0117.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1145.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0524.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1281.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0250.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1180.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1335.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0435.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0876.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0002.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0018.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0348.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1703.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1352.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1646.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0493.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1514.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0347.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0442.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0816.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1262.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1122.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0741.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1686.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0584.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0381.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1053.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0519.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1164.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0312.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1462.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0476.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0089.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1543.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0017.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1487.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0003.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1077.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0685.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1156.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1690.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0926.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0147.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0890.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0010.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0390.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1502.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0413.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0619.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0760.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1457.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1532.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1638.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0655.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1148.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0052.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0877.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1405.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0333.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0508.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1510.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0497.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1466.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1278.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1364.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0213.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0452.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0258.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0416.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0259.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1497.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1518.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1431.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0422.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0465.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0460.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0398.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1286.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1404.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1029.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0972.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0651.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1042.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1550.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0809.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0884.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0341.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0628.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0441.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1731.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0120.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0562.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1545.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0949.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0209.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1639.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1479.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0538.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1266.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1595.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0119.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0696.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1533.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0595.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0362.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0942.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0025.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1605.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1093.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1736.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0918.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1423.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1299.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1261.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1313.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0806.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0750.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1528.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0675.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0013.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1079.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0603.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0131.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1430.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1038.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0920.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0891.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1353.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0334.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0977.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0523.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1039.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0349.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1290.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0260.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0953.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1132.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0866.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0022.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1558.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0850.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0668.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0784.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1672.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0740.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1203.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0264.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0456.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0434.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1133.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1158.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0528.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0796.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1217.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1254.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0151.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0763.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0468.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0363.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0179.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0737.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1489.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1668.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1109.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0020.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1589.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0964.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1540.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0232.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1074.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0829.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0905.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0266.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0514.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1421.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1756.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0939.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0262.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1088.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1181.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1556.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1679.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0639.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1541.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0102.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0840.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0656.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0802.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1572.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0923.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0745.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0846.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0314.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0771.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1225.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0666.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1151.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0928.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1613.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1632.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0838.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1028.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0785.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1730.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0568.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1450.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1570.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0126.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1446.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0536.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0636.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1754.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0049.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1493.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0912.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0075.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0134.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0673.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1522.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0769.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1011.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0618.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1244.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0073.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0480.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1684.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1596.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0489.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1517.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0996.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1624.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1420.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0984.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0125.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1611.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0795.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1251.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0563.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1022.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0041.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0028.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1140.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1247.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0121.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1326.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1100.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1332.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1293.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0243.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0869.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1238.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0660.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0338.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0299.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0832.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1023.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1267.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0961.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0354.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0965.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1300.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1209.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0029.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0172.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0645.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0807.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1294.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0182.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0915.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1616.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1066.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0196.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1282.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0409.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0913.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1529.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0083.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0919.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1418.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1590.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1189.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0818.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0938.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1138.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0988.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0144.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1205.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0486.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0062.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1627.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0547.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1676.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1468.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1567.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1482.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0043.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1320.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1214.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0992.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0308.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0158.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0470.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1491.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1724.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0316.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0854.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1721.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1131.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1599.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0295.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0048.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0458.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0687.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0940.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0304.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1250.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1119.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0278.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0303.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1056.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0678.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1361.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0485.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1697.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1198.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0545.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1130.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0821.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1414.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1291.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1086.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0718.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0907.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0471.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0702.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0728.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0588.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0774.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1170.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0554.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0014.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0064.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0097.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1743.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0088.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0607.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1661.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0644.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0835.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1696.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0227.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0192.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1223.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1314.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0352.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1081.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0620.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1658.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1348.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0143.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0148.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0711.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1043.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1280.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1239.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1606.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1142.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0842.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1064.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1469.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0313.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0466.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1369.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0756.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1725.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0328.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1614.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1386.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0529.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1186.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0616.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0516.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0160.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1670.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0081.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0515.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0451.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0946.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1346.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0691.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1345.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1350.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0665.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0955.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1678.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1751.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/1192.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0254.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0670.jpg
# /kaggle/input/brain-tumor-mri-scans/pituitary/0153.jpg
# ...
# /kaggle/input/brain-tumor-mri-scans/glioma/0847.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1311.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1461.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0085.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0690.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1177.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0686.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1159.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0833.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1591.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0852.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1001.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0123.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0540.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0730.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1316.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0983.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1030.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1546.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0488.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1008.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0385.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0051.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1020.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0704.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0715.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0898.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1277.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1275.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1245.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1464.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0676.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0360.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0336.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0880.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0753.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0427.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0090.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0283.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1188.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0231.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0960.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1438.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0896.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0420.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0138.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1560.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0574.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0464.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0975.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1073.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1231.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0343.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1419.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1437.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1506.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1568.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1476.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0453.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1306.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0212.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0657.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1524.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0286.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1365.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0399.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1113.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1356.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0317.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0957.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0248.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0342.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0016.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1403.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1500.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1199.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0225.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1176.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0156.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0084.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0693.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0374.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0635.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0401.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1519.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0658.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0851.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0167.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0779.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0124.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1429.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0229.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0190.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0223.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0358.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0382.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0197.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0487.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0467.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1441.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0038.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0325.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1253.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0744.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0319.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0344.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0924.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0549.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0122.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1444.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0339.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0985.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1456.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1193.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0893.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1065.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0902.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1609.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0797.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1530.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1246.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0531.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0707.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1115.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1377.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1284.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1602.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1357.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0263.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0275.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0836.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1537.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1226.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0565.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0389.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1179.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0615.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0629.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1333.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0007.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1120.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1276.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0504.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0180.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0437.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0288.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1229.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0036.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1052.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1553.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1338.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1114.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1317.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1525.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0758.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0749.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0129.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1509.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0937.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0039.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0962.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0881.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1111.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0667.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0669.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0297.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1516.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0589.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1195.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0824.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0108.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0236.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0747.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1367.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0701.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0576.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1334.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0709.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0587.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1285.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0378.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0570.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0291.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0234.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0408.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1576.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1220.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0803.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0659.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0976.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1513.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0400.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1542.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0909.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1552.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0631.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0406.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1617.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1248.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0412.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0827.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1005.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0425.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0892.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0274.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0800.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0335.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1587.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0720.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1394.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1452.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1442.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0281.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0206.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0284.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0101.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0759.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1147.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0245.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1184.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0469.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0210.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1390.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1046.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1264.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1407.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0483.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0572.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0239.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0448.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0186.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1143.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1230.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1425.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1578.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1227.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1321.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0757.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1467.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0330.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1594.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1504.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0202.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0272.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0858.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1612.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0096.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0168.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1204.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0772.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0024.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1057.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1322.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0627.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0115.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0612.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1265.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0726.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0968.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1165.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0086.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1379.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1581.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0776.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1521.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0513.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1090.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0766.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1358.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1061.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0357.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1323.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0560.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1445.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1155.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1016.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0170.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0200.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0371.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1149.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1135.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1399.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1283.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0494.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0764.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0443.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0752.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0906.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0609.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1021.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0526.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1015.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1538.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1252.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0843.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1236.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0001.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1515.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1141.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0870.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0492.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0176.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0391.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0556.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0788.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/1201.jpg
# /kaggle/input/brain-tumor-mri-scans/glioma/0269.jpg

# %%
# CELL 1
import os, random, json, copy
from collections import OrderedDict, defaultdict
import numpy as np
import torch, torch.nn as nn
import torchvision.transforms as T
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader, Subset
from PIL import Image
from sklearn.metrics import precision_score, recall_score, f1_score

# Globals (same as your original)
SEED = 42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

NUM_CLIENTS = 6
DIRICHLET_ALPHA = 0.08  # kept from your original code
ROUNDS = 30
LOCAL_EPOCHS = 2
BATCH_SIZE = 16
IMAGE_SIZE = 224
ROOT = "/kaggle/input/brain-tumor-mri-scans"  # change if your dataset path differs

DELAY_PROB = 0.15
FEDBUFF_APPLY_MULT = 0.6
Q_VAL = 0.2

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

os.makedirs("/kaggle/working/logs", exist_ok=True)
print("Device:", DEVICE)
# Out:
# Device: cuda

# %%
# CELL 2
class BrainTumorDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted([d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))])
        self.class_to_idx = {c:i for i,c in enumerate(self.classes)}
        self.samples = []
        for c in self.classes:
            folder = os.path.join(root_dir, c)
            for f in sorted(os.listdir(folder)):
                if f.lower().endswith(("png","jpg","jpeg","tif","tiff")):
                    self.samples.append((os.path.join(folder, f), self.class_to_idx[c]))

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        path, lbl = self.samples[idx]
        img = Image.open(path).convert("RGB")
        if self.transform:
            img = self.transform(img)
        return img, lbl

transform_train = T.Compose([
    T.RandomResizedCrop(IMAGE_SIZE),
    T.RandomHorizontalFlip(),
    T.ToTensor(),
    T.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])
transform_eval = T.Compose([
    T.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    T.ToTensor(),
    T.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])
])

# quick instantiate to validate path (no transforms)
full_dataset = BrainTumorDataset(ROOT, transform=None)
print("Found classes:", full_dataset.classes)
print("Total images:", len(full_dataset))
# Out:
# Found classes: ['glioma', 'healthy', 'meningioma', 'pituitary']
# Total images: 7023

# %%
# CELL 3
num_total = len(full_dataset)
indices = np.arange(num_total)
np.random.seed(SEED)
np.random.shuffle(indices)

train_frac = 0.80
val_frac = 0.10
n_train = int(train_frac * num_total)
n_val = int(val_frac * num_total)

train_idx = indices[:n_train]
val_idx = indices[n_train:n_train + n_val]
test_idx = indices[n_train + n_val:]

central_val_loader = DataLoader(Subset(BrainTumorDataset(ROOT, transform=transform_eval), val_idx),
                                batch_size=BATCH_SIZE, shuffle=False)
central_test_loader = DataLoader(Subset(BrainTumorDataset(ROOT, transform=transform_eval), test_idx),
                                 batch_size=BATCH_SIZE, shuffle=False)

print(f"Split sizes -> train: {len(train_idx)}, val: {len(val_idx)}, test: {len(test_idx)}")
# Out:
# Split sizes -> train: 5618, val: 702, test: 703

# %%
# CELL 4
def create_dirichlet_split_from_indices(dataset, indices_pool, num_clients, alpha, min_size=30):
    idx_by_class = defaultdict(list)
    for idx in indices_pool:
        _, y = dataset.samples[idx]
        idx_by_class[y].append(idx)

    client_map = {i: [] for i in range(num_clients)}

    for cls, idxs in idx_by_class.items():
        idxs = idxs.copy()
        np.random.shuffle(idxs)
        props = np.random.dirichlet([alpha] * num_clients)
        props = props / props.sum()
        counts = (props * len(idxs)).astype(int)
        counts[-1] = len(idxs) - counts[:-1].sum()
        ptr = 0
        for i in range(num_clients):
            client_map[i].extend(idxs[ptr:ptr+counts[i]])
            ptr += counts[i]

    # ensure min samples
    small = [c for c in client_map if len(client_map[c]) < min_size]
    big = [c for c in client_map if len(client_map[c]) >= min_size]

    leftover = []
    for c in small:
        leftover.extend(client_map[c])
        client_map[c] = []

    if leftover and len(big) > 0:
        np.random.shuffle(leftover)
        share = len(leftover) // len(big)
        for i, c in enumerate(big):
            s = i * share
            e = s + share if i < len(big)-1 else len(leftover)
            client_map[c].extend(leftover[s:e])

    return client_map

client_map = create_dirichlet_split_from_indices(full_dataset, train_idx, NUM_CLIENTS, DIRICHLET_ALPHA, min_size=30)

# JSON-safe dump (convert numpy ints to python ints)
safe_map = {str(k): [int(x) for x in v] for k, v in client_map.items()}
with open('/kaggle/working/logs/client_map.json', 'w') as f:
    json.dump(safe_map, f)

print("Client map created. Per-client counts:")
for k in client_map:
    print(k, len(client_map[k]))
# Out:
# Client map created. Per-client counts:
# 0 1185
# 1 130
# 2 1592
# 3 120
# 4 2533
# 5 58

# %%
# CELL 5
client_loaders = {}
for cid, idxs in client_map.items():
    idxs_sh = idxs.copy()
    np.random.seed(SEED + cid)
    np.random.shuffle(idxs_sh)
    n_local_train = int(0.85 * len(idxs_sh))
    tr_idx = idxs_sh[:n_local_train]
    vl_idx = idxs_sh[n_local_train:]
    client_loaders[cid] = {
        "train": DataLoader(Subset(BrainTumorDataset(ROOT, transform=transform_train), tr_idx),
                            batch_size=BATCH_SIZE, shuffle=True,
                            generator=torch.Generator().manual_seed(SEED + cid)),
        "val": DataLoader(Subset(BrainTumorDataset(ROOT, transform=transform_eval), vl_idx),
                          batch_size=BATCH_SIZE, shuffle=False)
    }
print("Built client loaders.")
# Out:
# Built client loaders.

# %%
# CELL 6
class SimpleEffNet(nn.Module):
    def __init__(self, num_classes=4):
        super().__init__()
        self.backbone = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.IMAGENET1K_V1)
        in_f = self.backbone.classifier[1].in_features
        self.backbone.classifier = nn.Sequential(
            nn.Dropout(0.3),
            nn.Linear(in_f, 256),
            nn.ReLU(),
            nn.Linear(256, num_classes)
        )
        n_freeze = int(0.7 * len(list(self.backbone.features.parameters())))
        for i, p in enumerate(self.backbone.features.parameters()):
            if i < n_freeze:
                p.requires_grad = False

    def forward(self, x):
        return self.backbone(x)

def local_train(global_model, loader, epochs, use_fedprox=False, mu=0.08, lr=1e-3):
    if len(loader.dataset) == 0:
        return copy.deepcopy(global_model), 0.0

    model = copy.deepcopy(global_model).to(DEVICE)
    model.train()
    opt = torch.optim.AdamW([p for p in model.parameters() if p.requires_grad], lr=lr, weight_decay=5e-4)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=max(1, epochs))
    loss_fn = nn.CrossEntropyLoss()
    g_params = [p.detach().clone() for p in global_model.parameters()]

    losses = []
    for ep in range(epochs):
        for xb, yb in loader:
            xb, yb = xb.to(DEVICE), yb.to(DEVICE)
            opt.zero_grad()
            out = model(xb)
            loss = loss_fn(out, yb)
            if use_fedprox:
                prox = 0.0
                for lp, gp in zip(model.parameters(), g_params):
                    prox = prox + torch.norm(lp - gp.to(lp.device))**2
                loss = loss + (mu / 2.0) * prox
            loss.backward()
            torch.nn.utils.clip_grad_norm_([p for p in model.parameters() if p.requires_grad], 1.0)
            opt.step()
            losses.append(float(loss.detach().cpu().numpy()))
        scheduler.step()

    avg_loss = float(np.mean(losses)) if losses else 0.0
    return model, avg_loss

def fedavg_aggregate(global_model, client_models, weights=None):
    g_state = global_model.state_dict()
    new_state = OrderedDict()
    if weights is None:
        weights = [1.0/len(client_models)] * len(client_models)
    for k in g_state:
        if g_state[k].dtype == torch.int64:
            new_state[k] = g_state[k].clone()
            continue
        accum = None
        for i, cm in enumerate(client_models):
            val = cm.state_dict()[k].float().to(g_state[k].device)
            w = weights[i]
            accum = val * w if accum is None else accum + val * w
        new_state[k] = accum.type_as(g_state[k])
    return new_state

class FedBuff:
    def __init__(self):
        self.buffer = []
    def add(self, state, samples, rnd):
        self.buffer.append({"state": {k:v.clone().cpu() for k,v in state.items()}, "samples": samples, "round": rnd})
    def apply(self, current_state, cur_round, apply_prob=0.4, max_age=8, apply_mult=FEDBUFF_APPLY_MULT):
        new_state = OrderedDict((k, v.clone()) for k,v in current_state.items())
        self.buffer = [b for b in self.buffer if (cur_round - b["round"]) <= max_age]
        apply_indices = [i for i in range(len(self.buffer)) if random.random() < apply_prob]
        for idx in sorted(apply_indices, reverse=True):
            b = self.buffer[idx]
            for k in new_state:
                if new_state[k].dtype != torch.int64:
                    delta = b["state"][k].to(new_state[k].device) - new_state[k]
                    new_state[k] = new_state[k] + apply_mult * delta
            del self.buffer[idx]
        return new_state

def compute_q_weights(losses, samples, q=Q_VAL, eps=1e-8):
    w = []
    for i in range(len(samples)):
        L = max(losses[i], eps)
        w.append(samples[i] * ((L + eps) ** q))
    s = sum(w)
    if s <= 0:
        return [s_i / sum(samples) for s_i in samples]
    return [wi / s for wi in w]

def evaluate(model, loader):
    if len(loader.dataset) == 0:
        return 0,0,0,0
    model.eval()
    preds, labels = [], []
    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(DEVICE), yb.to(DEVICE)
            p = model(xb).argmax(1)
            preds.extend(p.cpu().numpy().tolist())
            labels.extend(yb.cpu().numpy().tolist())
    preds = np.array(preds); labels = np.array(labels)
    acc = 100 * np.mean(preds == labels)
    prec = precision_score(labels, preds, average="macro", zero_division=0)
    rec = recall_score(labels, preds, average="macro", zero_division=0)
    f1 = f1_score(labels, preds, average="macro", zero_division=0)
    return acc, prec, rec, f1

def print_summary(r, stats):
    print(f"""
================ ROUND {r} ================
Acc        : {stats['acc']:.2f}%
Precision  : {stats['prec']:.3f}
Recall     : {stats['rec']:.3f}
F1 Score   : {stats['f1']:.3f}
Fairness   : {stats['fairness']:.3f}
Avg Stale  : {stats['avg_stale']:.3f}
ClientLoss : {[round(x, 3) for x in stats['losses']]}
Active     : {stats['active']}
Delayed    : {stats['delayed']}
===========================================
""")

# %%
# CELL 7
print("Running FedAvg | DIRICHLET_ALPHA =", DIRICHLET_ALPHA)
NUM_CLASSES = len(full_dataset.classes)
model = SimpleEffNet(num_classes=NUM_CLASSES).to(DEVICE)
log_data = []

for r in range(ROUNDS):
    active = list(client_loaders.keys())
    delayed = []
    client_models, client_losses, client_samples = [], [], []

    for cid in active:
        lm, loss = local_train(model, client_loaders[cid]["train"], LOCAL_EPOCHS)
        client_models.append(lm)
        client_losses.append(loss)
        client_samples.append(len(client_loaders[cid]["train"].dataset))

    if client_models:
        w = [s / sum(client_samples) for s in client_samples]
        new_state = fedavg_aggregate(model, client_models, w)
        model.load_state_dict(new_state)

    gacc, prec, rec, f1 = evaluate(model, central_val_loader)
    fairness = float(np.std([evaluate(model, client_loaders[c]["val"])[0] for c in client_loaders]))

    stats = {"round": r, "acc": gacc, "prec": prec, "rec": rec, "f1": f1,
             "fairness": fairness, "avg_stale": 0, "losses": client_losses,
             "active": active, "delayed": delayed}
    print_summary(r, stats)
    log_data.append(stats)

save_path = f"/kaggle/working/logs/FedAvg_alpha_{DIRICHLET_ALPHA}.json"
with open(save_path, "w") as f: json.dump(log_data, f, indent=2)
torch.save(model.state_dict(), f"/kaggle/working/logs/FedAvg_alpha_{DIRICHLET_ALPHA}_final.pth")
print("FedAvg finished, model saved.")
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# Running FedAvg | DIRICHLET_ALPHA = 0.08
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 143MB/s]
# ================ ROUND 0 ================
# Acc        : 43.59%
# Precision  : 0.236
# Recall     : 0.489
# F1 Score   : 0.311
# Fairness   : 36.143
# Avg Stale  : 0.000
# ClientLoss : [0.149, 0.218, 0.201, 0.205, 0.189, 0.68]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 1 ================
# Acc        : 44.02%
# Precision  : 0.251
# Recall     : 0.494
# F1 Score   : 0.321
# Fairness   : 36.084
# Avg Stale  : 0.000
# ClientLoss : [0.152, 0.266, 0.156, 0.562, 0.16, 1.163]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 2 ================
# Acc        : 44.16%
# Precision  : 0.234
# Recall     : 0.495
# F1 Score   : 0.312
# Fairness   : 36.408
# Avg Stale  : 0.000
# ClientLoss : [0.108, 0.184, 0.123, 0.405, 0.118, 0.854]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 3 ================
# Acc        : 44.02%
# Precision  : 0.235
# Recall     : 0.493
# F1 Score   : 0.313
# Fairness   : 36.585
# Avg Stale  : 0.000
# ClientLoss : [0.12, 0.192, 0.118, 0.438, 0.109, 1.567]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 4 ================
# Acc        : 44.02%
# Precision  : 0.508
# Recall     : 0.494
# F1 Score   : 0.326
# Fairness   : 36.143
# Avg Stale  : 0.000
# ClientLoss : [0.117, 0.124, 0.098, 0.564, 0.095, 2.0]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 5 ================
# Acc        : 43.73%
# Precision  : 0.221
# Recall     : 0.490
# F1 Score   : 0.303
# Fairness   : 36.467
# Avg Stale  : 0.000
# ClientLoss : [0.119, 0.125, 0.108, 0.681, 0.081, 1.289]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 6 ================
# Acc        : 45.30%
# Precision  : 0.483
# Recall     : 0.505
# F1 Score   : 0.345
# Fairness   : 35.224
# Avg Stale  : 0.000
# ClientLoss : [0.102, 0.117, 0.092, 0.427, 0.087, 1.089]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 7 ================
# Acc        : 44.30%
# Precision  : 0.484
# Recall     : 0.496
# F1 Score   : 0.314
# Fairness   : 36.585
# Avg Stale  : 0.000
# ClientLoss : [0.104, 0.132, 0.083, 0.674, 0.081, 1.34]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 8 ================
# Acc        : 44.59%
# Precision  : 0.473
# Recall     : 0.498
# F1 Score   : 0.314
# Fairness   : 36.438
# Avg Stale  : 0.000
# ClientLoss : [0.125, 0.066, 0.069, 0.765, 0.065, 1.52]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 9 ================
# Acc        : 44.30%
# Precision  : 0.259
# Recall     : 0.497
# F1 Score   : 0.326
# Fairness   : 36.497
# Avg Stale  : 0.000
# ClientLoss : [0.108, 0.096, 0.075, 0.718, 0.08, 1.222]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 10 ================
# Acc        : 47.01%
# Precision  : 0.472
# Recall     : 0.517
# F1 Score   : 0.356
# Fairness   : 34.990
# Avg Stale  : 0.000
# ClientLoss : [0.14, 0.05, 0.091, 1.102, 0.058, 2.222]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 11 ================
# Acc        : 44.30%
# Precision  : 0.257
# Recall     : 0.497
# F1 Score   : 0.325
# Fairness   : 36.470
# Avg Stale  : 0.000
# ClientLoss : [0.121, 0.045, 0.087, 0.998, 0.06, 1.763]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 12 ================
# Acc        : 45.87%
# Precision  : 0.485
# Recall     : 0.509
# F1 Score   : 0.338
# Fairness   : 34.896
# Avg Stale  : 0.000
# ClientLoss : [0.109, 0.077, 0.076, 0.93, 0.054, 2.943]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 13 ================
# Acc        : 61.40%
# Precision  : 0.512
# Recall     : 0.630
# F1 Score   : 0.523
# Fairness   : 35.021
# Avg Stale  : 0.000
# ClientLoss : [0.14, 0.071, 0.071, 0.676, 0.057, 1.631]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 14 ================
# Acc        : 44.59%
# Precision  : 0.486
# Recall     : 0.499
# F1 Score   : 0.319
# Fairness   : 36.587
# Avg Stale  : 0.000
# ClientLoss : [0.1, 0.064, 0.063, 0.625, 0.048, 2.295]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 15 ================
# Acc        : 50.71%
# Precision  : 0.487
# Recall     : 0.546
# F1 Score   : 0.405
# Fairness   : 33.790
# Avg Stale  : 0.000
# ClientLoss : [0.139, 0.046, 0.069, 1.207, 0.05, 2.747]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 16 ================
# Acc        : 50.85%
# Precision  : 0.474
# Recall     : 0.547
# F1 Score   : 0.413
# Fairness   : 33.288
# Avg Stale  : 0.000
# ClientLoss : [0.128, 0.089, 0.069, 1.058, 0.056, 1.732]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 17 ================
# Acc        : 57.69%
# Precision  : 0.496
# Recall     : 0.601
# F1 Score   : 0.486
# Fairness   : 33.943
# Avg Stale  : 0.000
# ClientLoss : [0.118, 0.031, 0.058, 0.537, 0.042, 2.51]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 18 ================
# Acc        : 46.30%
# Precision  : 0.442
# Recall     : 0.512
# F1 Score   : 0.345
# Fairness   : 35.679
# Avg Stale  : 0.000
# ClientLoss : [0.075, 0.077, 0.084, 0.46, 0.054, 2.466]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 19 ================
# Acc        : 52.14%
# Precision  : 0.498
# Recall     : 0.559
# F1 Score   : 0.431
# Fairness   : 33.541
# Avg Stale  : 0.000
# ClientLoss : [0.09, 0.069, 0.073, 1.047, 0.053, 1.657]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 20 ================
# Acc        : 55.56%
# Precision  : 0.523
# Recall     : 0.586
# F1 Score   : 0.476
# Fairness   : 33.924
# Avg Stale  : 0.000
# ClientLoss : [0.131, 0.056, 0.063, 0.851, 0.049, 2.253]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 21 ================
# Acc        : 51.42%
# Precision  : 0.490
# Recall     : 0.553
# F1 Score   : 0.417
# Fairness   : 33.330
# Avg Stale  : 0.000
# ClientLoss : [0.087, 0.039, 0.059, 0.356, 0.04, 1.393]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 22 ================
# Acc        : 48.15%
# Precision  : 0.469
# Recall     : 0.528
# F1 Score   : 0.370
# Fairness   : 33.936
# Avg Stale  : 0.000
# ClientLoss : [0.153, 0.045, 0.054, 0.807, 0.04, 1.636]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 23 ================
# Acc        : 47.01%
# Precision  : 0.476
# Recall     : 0.517
# F1 Score   : 0.353
# Fairness   : 33.851
# Avg Stale  : 0.000
# ClientLoss : [0.097, 0.033, 0.065, 0.695, 0.041, 2.585]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 24 ================
# Acc        : 48.58%
# Precision  : 0.492
# Recall     : 0.531
# F1 Score   : 0.388
# Fairness   : 33.960
# Avg Stale  : 0.000
# ClientLoss : [0.16, 0.054, 0.073, 1.643, 0.041, 3.146]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 25 ================
# Acc        : 48.15%
# Precision  : 0.471
# Recall     : 0.528
# F1 Score   : 0.383
# Fairness   : 34.129
# Avg Stale  : 0.000
# ClientLoss : [0.139, 0.029, 0.068, 0.669, 0.041, 1.932]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 26 ================
# Acc        : 58.26%
# Precision  : 0.509
# Recall     : 0.607
# F1 Score   : 0.497
# Fairness   : 34.426
# Avg Stale  : 0.000
# ClientLoss : [0.1, 0.04, 0.058, 0.568, 0.041, 2.992]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 27 ================
# Acc        : 55.84%
# Precision  : 0.521
# Recall     : 0.587
# F1 Score   : 0.477
# Fairness   : 33.510
# Avg Stale  : 0.000
# ClientLoss : [0.129, 0.028, 0.085, 1.228, 0.055, 2.176]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 28 ================
# Acc        : 54.56%
# Precision  : 0.505
# Recall     : 0.578
# F1 Score   : 0.457
# Fairness   : 33.351
# Avg Stale  : 0.000
# ClientLoss : [0.142, 0.06, 0.071, 0.555, 0.048, 2.499]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 29 ================
# Acc        : 57.41%
# Precision  : 0.528
# Recall     : 0.600
# F1 Score   : 0.495
# Fairness   : 33.863
# Avg Stale  : 0.000
# ClientLoss : [0.102, 0.093, 0.077, 0.44, 0.036, 1.908]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
# FedAvg finished, model saved.

# %%
# CELL 8
print("Running FedBuff | DIRICHLET_ALPHA =", DIRICHLET_ALPHA)
model = SimpleEffNet(num_classes=NUM_CLASSES).to(DEVICE)
buffer = FedBuff()
log_data = []
staleness = {cid: 0 for cid in client_map}

for r in range(ROUNDS):
    active, delayed = [], []
    for cid in client_loaders:
        if random.random() < 0.25:
            delayed.append(cid); staleness[cid] += 1
        else:
            active.append(cid); staleness[cid] = 0

    client_models, client_losses, client_samples = [], [], []
    for cid in active:
        lm, loss = local_train(model, client_loaders[cid]["train"], LOCAL_EPOCHS)
        client_models.append(lm); client_losses.append(loss)
        client_samples.append(len(client_loaders[cid]["train"].dataset))

    for cid in delayed:
        lm, loss = local_train(model, client_loaders[cid]["train"], LOCAL_EPOCHS)
        buffer.add(lm.state_dict(), len(client_loaders[cid]["train"].dataset), r)

    if client_models:
        w = [s / sum(client_samples) for s in client_samples]
        model.load_state_dict(fedavg_aggregate(model, client_models, w))

    model.load_state_dict(buffer.apply(model.state_dict(), cur_round=r))
    gacc, prec, rec, f1 = evaluate(model, central_val_loader)
    fairness = float(np.std([evaluate(model, client_loaders[c]["val"])[0] for c in client_loaders]))
    avg_stale = float(np.mean(list(staleness.values()))) if len(staleness)>0 else 0.0

    stats = {"round": r, "acc": gacc, "prec": prec, "rec": rec, "f1": f1,
             "fairness": fairness, "avg_stale": avg_stale, "losses": client_losses,
             "active": active, "delayed": delayed}
    print_summary(r, stats); log_data.append(stats)

with open(f"/kaggle/working/logs/FedBuff_alpha_{DIRICHLET_ALPHA}.json", "w") as f: json.dump(log_data, f, indent=2)
torch.save(model.state_dict(), f"/kaggle/working/logs/FedBuff_alpha_{DIRICHLET_ALPHA}_final.pth")
print("FedBuff finished, model saved.")
# Out:
# Running FedBuff | DIRICHLET_ALPHA = 0.08
#
# ================ ROUND 0 ================
# Acc        : 23.50%
# Precision  : 0.059
# Recall     : 0.250
# F1 Score   : 0.095
# Fairness   : 44.508
# Avg Stale  : 0.333
# ClientLoss : [0.143, 0.19, 0.2, 0.702]
# Active     : [0, 2, 4, 5]
# Delayed    : [1, 3]
# ===========================================
#
#
# ================ ROUND 1 ================
# Acc        : 68.52%
# Precision  : 0.530
# Recall     : 0.676
# F1 Score   : 0.585
# Fairness   : 41.916
# Avg Stale  : 0.833
# ClientLoss : [0.099, 0.002]
# Active     : [0, 3]
# Delayed    : [1, 2, 4, 5]
# ===========================================
#
#
# ================ ROUND 2 ================
# Acc        : 32.48%
# Precision  : 0.354
# Recall     : 0.257
# F1 Score   : 0.138
# Fairness   : 42.914
# Avg Stale  : 0.500
# ClientLoss : [0.008, 0.139, 1.135, 2.142]
# Active     : [1, 2, 3, 5]
# Delayed    : [0, 4]
# ===========================================
#
#
# ================ ROUND 3 ================
# Acc        : 42.59%
# Precision  : 0.212
# Recall     : 0.475
# F1 Score   : 0.293
# Fairness   : 35.291
# Avg Stale  : 0.000
# ClientLoss : [0.293, 0.004, 0.193, 2.221, 0.247, 3.347]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 4 ================
# Acc        : 61.82%
# Precision  : 0.796
# Recall     : 0.621
# F1 Score   : 0.631
# Fairness   : 18.370
# Avg Stale  : 0.667
# ClientLoss : [0.165, 0.768]
# Active     : [0, 3]
# Delayed    : [1, 2, 4, 5]
# ===========================================
#
#
# ================ ROUND 5 ================
# Acc        : 44.02%
# Precision  : 0.279
# Recall     : 0.494
# F1 Score   : 0.335
# Fairness   : 36.143
# Avg Stale  : 0.500
# ClientLoss : [0.071, 0.672, 0.176, 0.193]
# Active     : [0, 1, 2, 4]
# Delayed    : [3, 5]
# ===========================================
#
#
# ================ ROUND 6 ================
# Acc        : 63.11%
# Precision  : 0.689
# Recall     : 0.647
# F1 Score   : 0.637
# Fairness   : 7.207
# Avg Stale  : 0.667
# ClientLoss : [0.288, 1.543, 0.204, 2.059]
# Active     : [0, 1, 2, 3]
# Delayed    : [4, 5]
# ===========================================
#
#
# ================ ROUND 7 ================
# Acc        : 43.30%
# Precision  : 0.219
# Recall     : 0.484
# F1 Score   : 0.300
# Fairness   : 36.438
# Avg Stale  : 0.000
# ClientLoss : [0.094, 1.641, 0.263, 0.0, 0.201, 0.542]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 8 ================
# Acc        : 46.44%
# Precision  : 0.627
# Recall     : 0.506
# F1 Score   : 0.386
# Fairness   : 31.593
# Avg Stale  : 0.167
# ClientLoss : [0.206, 0.13, 0.218, 0.115, 0.602]
# Active     : [1, 2, 3, 4, 5]
# Delayed    : [0]
# ===========================================
#
#
# ================ ROUND 9 ================
# Acc        : 44.30%
# Precision  : 0.252
# Recall     : 0.497
# F1 Score   : 0.323
# Fairness   : 36.674
# Avg Stale  : 0.500
# ClientLoss : [0.063, 0.654, 0.586]
# Active     : [0, 1, 5]
# Delayed    : [2, 3, 4]
# ===========================================
#
#
# ================ ROUND 10 ================
# Acc        : 44.73%
# Precision  : 0.383
# Recall     : 0.499
# F1 Score   : 0.325
# Fairness   : 36.443
# Avg Stale  : 0.167
# ClientLoss : [0.121, 0.898, 0.17, 0.518, 0.09]
# Active     : [0, 1, 2, 3, 4]
# Delayed    : [5]
# ===========================================
#
#
# ================ ROUND 11 ================
# Acc        : 65.95%
# Precision  : 0.758
# Recall     : 0.664
# F1 Score   : 0.566
# Fairness   : 37.372
# Avg Stale  : 0.167
# ClientLoss : [0.071, 0.202, 0.223, 0.089, 0.814]
# Active     : [0, 1, 3, 4, 5]
# Delayed    : [2]
# ===========================================
#
#
# ================ ROUND 12 ================
# Acc        : 44.16%
# Precision  : 0.512
# Recall     : 0.494
# F1 Score   : 0.331
# Fairness   : 35.533
# Avg Stale  : 0.167
# ClientLoss : [0.058, 0.741, 0.141, 0.001, 0.127]
# Active     : [0, 1, 2, 3, 4]
# Delayed    : [5]
# ===========================================
#
#
# ================ ROUND 13 ================
# Acc        : 60.68%
# Precision  : 0.753
# Recall     : 0.631
# F1 Score   : 0.563
# Fairness   : 29.730
# Avg Stale  : 0.333
# ClientLoss : [0.114, 0.084, 0.092, 1.938]
# Active     : [0, 2, 4, 5]
# Delayed    : [1, 3]
# ===========================================
#
#
# ================ ROUND 14 ================
# Acc        : 72.65%
# Precision  : 0.721
# Recall     : 0.721
# F1 Score   : 0.715
# Fairness   : 13.991
# Avg Stale  : 0.500
# ClientLoss : [0.398, 0.026, 0.095]
# Active     : [1, 3, 4]
# Delayed    : [0, 2, 5]
# ===========================================
#
#
# ================ ROUND 15 ================
# Acc        : 71.65%
# Precision  : 0.787
# Recall     : 0.692
# F1 Score   : 0.635
# Fairness   : 38.800
# Avg Stale  : 0.333
# ClientLoss : [0.045, 1.057, 0.001, 0.099, 0.533]
# Active     : [0, 1, 3, 4, 5]
# Delayed    : [2]
# ===========================================
#
#
# ================ ROUND 16 ================
# Acc        : 51.42%
# Precision  : 0.547
# Recall     : 0.482
# F1 Score   : 0.419
# Fairness   : 40.062
# Avg Stale  : 1.000
# ClientLoss : [0.045, 0.155]
# Active     : [0, 4]
# Delayed    : [1, 2, 3, 5]
# ===========================================
#
#
# ================ ROUND 17 ================
# Acc        : 74.93%
# Precision  : 0.565
# Recall     : 0.734
# F1 Score   : 0.632
# Fairness   : 44.016
# Avg Stale  : 0.167
# ClientLoss : [0.0, 0.074, 2.425, 0.198, 4.273]
# Active     : [1, 2, 3, 4, 5]
# Delayed    : [0]
# ===========================================
#
#
# ================ ROUND 18 ================
# Acc        : 45.30%
# Precision  : 0.730
# Recall     : 0.502
# F1 Score   : 0.334
# Fairness   : 34.402
# Avg Stale  : 0.167
# ClientLoss : [0.361, 0.0, 0.081, 3.091, 5.023]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 19 ================
# Acc        : 74.93%
# Precision  : 0.559
# Recall     : 0.733
# F1 Score   : 0.631
# Fairness   : 44.089
# Avg Stale  : 0.500
# ClientLoss : [0.495, 0.104, 0.007, 0.314]
# Active     : [1, 2, 3, 5]
# Delayed    : [0, 4]
# ===========================================
#
#
# ================ ROUND 20 ================
# Acc        : 44.16%
# Precision  : 0.613
# Recall     : 0.492
# F1 Score   : 0.323
# Fairness   : 35.368
# Avg Stale  : 0.333
# ClientLoss : [0.005, 0.062, 3.487, 0.176, 5.228]
# Active     : [1, 2, 3, 4, 5]
# Delayed    : [0]
# ===========================================
#
#
# ================ ROUND 21 ================
# Acc        : 50.43%
# Precision  : 0.509
# Recall     : 0.545
# F1 Score   : 0.414
# Fairness   : 33.365
# Avg Stale  : 0.500
# ClientLoss : [0.948, 0.152, 0.002, 0.102, 1.369]
# Active     : [1, 2, 3, 4, 5]
# Delayed    : [0]
# ===========================================
#
#
# ================ ROUND 22 ================
# Acc        : 73.50%
# Precision  : 0.799
# Recall     : 0.734
# F1 Score   : 0.673
# Fairness   : 35.678
# Avg Stale  : 0.167
# ClientLoss : [0.213, 0.791, 1.759, 0.072, 2.502]
# Active     : [0, 1, 3, 4, 5]
# Delayed    : [2]
# ===========================================
#
#
# ================ ROUND 23 ================
# Acc        : 75.64%
# Precision  : 0.570
# Recall     : 0.741
# F1 Score   : 0.639
# Fairness   : 44.146
# Avg Stale  : 0.667
# ClientLoss : [0.028, 0.965, 0.006]
# Active     : [0, 1, 3]
# Delayed    : [2, 4, 5]
# ===========================================
#
#
# ================ ROUND 24 ================
# Acc        : 56.41%
# Precision  : 0.762
# Recall     : 0.593
# F1 Score   : 0.483
# Fairness   : 34.253
# Avg Stale  : 0.000
# ClientLoss : [0.296, 0.004, 0.054, 2.477, 0.137, 4.072]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 25 ================
# Acc        : 50.28%
# Precision  : 0.486
# Recall     : 0.543
# F1 Score   : 0.405
# Fairness   : 33.426
# Avg Stale  : 0.167
# ClientLoss : [0.04, 0.8, 0.159, 0.004, 0.081]
# Active     : [0, 1, 2, 3, 4]
# Delayed    : [5]
# ===========================================
#
#
# ================ ROUND 26 ================
# Acc        : 71.79%
# Precision  : 0.809
# Recall     : 0.722
# F1 Score   : 0.665
# Fairness   : 33.232
# Avg Stale  : 0.333
# ClientLoss : [0.106, 0.663, 0.091, 2.619]
# Active     : [0, 3, 4, 5]
# Delayed    : [1, 2]
# ===========================================
#
#
# ================ ROUND 27 ================
# Acc        : 53.70%
# Precision  : 0.825
# Recall     : 0.489
# F1 Score   : 0.386
# Fairness   : 34.709
# Avg Stale  : 0.167
# ClientLoss : [0.039, 0.157, 0.086, 0.048, 1.002]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 28 ================
# Acc        : 46.01%
# Precision  : 0.492
# Recall     : 0.510
# F1 Score   : 0.345
# Fairness   : 35.486
# Avg Stale  : 0.500
# ClientLoss : [0.001, 0.192, 1.47]
# Active     : [3, 4, 5]
# Delayed    : [0, 1, 2]
# ===========================================
#
#
# ================ ROUND 29 ================
# Acc        : 74.07%
# Precision  : 0.565
# Recall     : 0.728
# F1 Score   : 0.627
# Fairness   : 43.262
# Avg Stale  : 0.500
# ClientLoss : [0.184, 0.86, 1.322, 0.065]
# Active     : [0, 1, 3, 4]
# Delayed    : [2, 5]
# ===========================================
#
# FedBuff finished, model saved.

# %%
# CELL 9
print("Running QFedAvg + FedBuff | DIRICHLET_ALPHA =", DIRICHLET_ALPHA)
model = SimpleEffNet(num_classes=NUM_CLASSES).to(DEVICE)
buffer = FedBuff()
log_data = []
staleness = {cid: 0 for cid in client_map}

for r in range(ROUNDS):
    active, delayed = [], []
    for cid in client_loaders:
        if random.random() < DELAY_PROB:
            delayed.append(cid); staleness[cid] += 1
        else:
            active.append(cid); staleness[cid] = 0

    client_models, client_losses, client_samples = [], [], []
    for cid in active:
        lm, loss = local_train(model, client_loaders[cid]["train"], LOCAL_EPOCHS, use_fedprox=False)
        client_models.append(lm); client_losses.append(loss)
        client_samples.append(len(client_loaders[cid]["train"].dataset))

    for cid in delayed:
        lm, loss = local_train(model, client_loaders[cid]["train"], LOCAL_EPOCHS, use_fedprox=False)
        buffer.add(lm.state_dict(), len(client_loaders[cid]["train"].dataset), r)

    if len(client_models) > 0:
        q_weights = compute_q_weights(client_losses, client_samples, q=Q_VAL)
        model.load_state_dict(fedavg_aggregate(model, client_models, q_weights))

    model.load_state_dict(buffer.apply(model.state_dict(), cur_round=r, apply_prob=0.4, max_age=8, apply_mult=FEDBUFF_APPLY_MULT))

    gacc, prec, rec, f1 = evaluate(model, central_val_loader)
    accs = [evaluate(model, client_loaders[c]["val"])[0] for c in client_loaders]
    fairness = float(np.std(accs))
    avg_stale = float(np.mean(list(staleness.values())))

    stats = {"round": r, "acc": gacc, "prec": prec, "rec": rec, "f1": f1,
             "fairness": fairness, "avg_stale": avg_stale, "losses": client_losses,
             "active": active, "delayed": delayed}
    print_summary(r, stats); log_data.append(stats)

with open(f"/kaggle/working/logs/QFedAvg_FedBuff_ALPHA_{DIRICHLET_ALPHA}.json", "w") as f: json.dump(log_data, f, indent=2)
torch.save(model.state_dict(), f"/kaggle/working/logs/QFedAvg_FedBuff_ALPHA_{DIRICHLET_ALPHA}_final.pth")
print("QFedAvg+FedBuff finished, model saved.")
# Out:
# Running QFedAvg + FedBuff | DIRICHLET_ALPHA = 0.08
#
# ================ ROUND 0 ================
# Acc        : 55.13%
# Precision  : 0.469
# Recall     : 0.576
# F1 Score   : 0.461
# Fairness   : 32.881
# Avg Stale  : 0.333
# ClientLoss : [0.146, 0.204, 0.2, 1.262]
# Active     : [0, 3, 4, 5]
# Delayed    : [1, 2]
# ===========================================
#
#
# ================ ROUND 1 ================
# Acc        : 54.84%
# Precision  : 0.478
# Recall     : 0.571
# F1 Score   : 0.460
# Fairness   : 33.058
# Avg Stale  : 0.500
# ClientLoss : [0.273, 0.928, 0.135, 1.919]
# Active     : [2, 3, 4, 5]
# Delayed    : [0, 1]
# ===========================================
#
#
# ================ ROUND 2 ================
# Acc        : 43.87%
# Precision  : 0.245
# Recall     : 0.491
# F1 Score   : 0.317
# Fairness   : 36.674
# Avg Stale  : 0.000
# ClientLoss : [0.169, 0.006, 0.137, 0.858, 0.194, 1.702]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 3 ================
# Acc        : 44.02%
# Precision  : 0.238
# Recall     : 0.494
# F1 Score   : 0.314
# Fairness   : 36.585
# Avg Stale  : 0.167
# ClientLoss : [0.109, 0.274, 0.135, 0.117, 1.429]
# Active     : [0, 1, 2, 4, 5]
# Delayed    : [3]
# ===========================================
#
#
# ================ ROUND 4 ================
# Acc        : 57.41%
# Precision  : 0.771
# Recall     : 0.578
# F1 Score   : 0.584
# Fairness   : 19.490
# Avg Stale  : 0.167
# ClientLoss : [0.121, 0.064, 0.1, 0.465, 1.516]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 5 ================
# Acc        : 50.71%
# Precision  : 0.512
# Recall     : 0.462
# F1 Score   : 0.428
# Fairness   : 39.635
# Avg Stale  : 0.333
# ClientLoss : [0.069, 0.697, 0.172, 0.002, 0.673]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 6 ================
# Acc        : 43.73%
# Precision  : 0.260
# Recall     : 0.491
# F1 Score   : 0.325
# Fairness   : 36.408
# Avg Stale  : 0.000
# ClientLoss : [0.282, 0.0, 0.14, 1.88, 0.25, 3.377]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 7 ================
# Acc        : 44.02%
# Precision  : 0.243
# Recall     : 0.494
# F1 Score   : 0.316
# Fairness   : 36.585
# Avg Stale  : 0.167
# ClientLoss : [0.375, 1.275, 0.22, 0.101, 3.797]
# Active     : [0, 1, 2, 4, 5]
# Delayed    : [3]
# ===========================================
#
#
# ================ ROUND 8 ================
# Acc        : 43.73%
# Precision  : 0.231
# Recall     : 0.490
# F1 Score   : 0.309
# Fairness   : 36.041
# Avg Stale  : 0.167
# ClientLoss : [0.288, 1.143, 0.187, 2.214, 0.093]
# Active     : [0, 1, 2, 3, 4]
# Delayed    : [5]
# ===========================================
#
#
# ================ ROUND 9 ================
# Acc        : 48.43%
# Precision  : 0.553
# Recall     : 0.511
# F1 Score   : 0.465
# Fairness   : 20.714
# Avg Stale  : 0.167
# ClientLoss : [0.125, 0.097, 0.095, 0.669, 1.403]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 10 ================
# Acc        : 44.30%
# Precision  : 0.256
# Recall     : 0.497
# F1 Score   : 0.325
# Fairness   : 36.497
# Avg Stale  : 0.000
# ClientLoss : [0.059, 0.423, 0.124, 0.015, 0.125, 0.47]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 11 ================
# Acc        : 44.02%
# Precision  : 0.225
# Recall     : 0.493
# F1 Score   : 0.307
# Fairness   : 36.497
# Avg Stale  : 0.000
# ClientLoss : [0.387, 1.815, 0.22, 3.04, 0.078, 5.753]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 12 ================
# Acc        : 44.02%
# Precision  : 0.250
# Recall     : 0.494
# F1 Score   : 0.320
# Fairness   : 36.674
# Avg Stale  : 0.167
# ClientLoss : [0.119, 0.092, 0.765, 0.076, 1.323]
# Active     : [0, 2, 3, 4, 5]
# Delayed    : [1]
# ===========================================
#
#
# ================ ROUND 13 ================
# Acc        : 68.52%
# Precision  : 0.560
# Recall     : 0.660
# F1 Score   : 0.594
# Fairness   : 41.455
# Avg Stale  : 0.000
# ClientLoss : [0.118, 0.312, 0.1, 0.555, 0.077, 1.767]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 14 ================
# Acc        : 47.44%
# Precision  : 0.499
# Recall     : 0.520
# F1 Score   : 0.371
# Fairness   : 35.390
# Avg Stale  : 0.000
# ClientLoss : [0.226, 0.0, 0.096, 1.869, 0.095, 3.623]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 15 ================
# Acc        : 75.21%
# Precision  : 0.583
# Recall     : 0.739
# F1 Score   : 0.641
# Fairness   : 43.869
# Avg Stale  : 0.167
# ClientLoss : [0.145, 0.38, 0.86, 0.069, 2.107]
# Active     : [0, 1, 3, 4, 5]
# Delayed    : [2]
# ===========================================
#
#
# ================ ROUND 16 ================
# Acc        : 49.00%
# Precision  : 0.488
# Recall     : 0.533
# F1 Score   : 0.395
# Fairness   : 33.546
# Avg Stale  : 0.000
# ClientLoss : [0.226, 0.002, 0.07, 1.809, 0.091, 2.942]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 17 ================
# Acc        : 37.04%
# Precision  : 0.577
# Recall     : 0.312
# F1 Score   : 0.228
# Fairness   : 42.404
# Avg Stale  : 0.333
# ClientLoss : [0.111, 0.066, 0.748, 2.277]
# Active     : [0, 2, 3, 5]
# Delayed    : [1, 4]
# ===========================================
#
#
# ================ ROUND 18 ================
# Acc        : 59.83%
# Precision  : 0.537
# Recall     : 0.619
# F1 Score   : 0.518
# Fairness   : 35.388
# Avg Stale  : 0.333
# ClientLoss : [0.182, 0.059, 1.532, 0.149, 2.618]
# Active     : [0, 2, 3, 4, 5]
# Delayed    : [1]
# ===========================================
#
#
# ================ ROUND 19 ================
# Acc        : 67.95%
# Precision  : 0.531
# Recall     : 0.680
# F1 Score   : 0.577
# Fairness   : 39.854
# Avg Stale  : 0.000
# ClientLoss : [0.145, 0.392, 0.084, 0.893, 0.06, 2.557]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 20 ================
# Acc        : 57.26%
# Precision  : 0.519
# Recall     : 0.598
# F1 Score   : 0.491
# Fairness   : 33.899
# Avg Stale  : 0.000
# ClientLoss : [0.075, 0.053, 0.085, 0.532, 0.062, 0.781]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 21 ================
# Acc        : 72.93%
# Precision  : 0.552
# Recall     : 0.712
# F1 Score   : 0.618
# Fairness   : 43.291
# Avg Stale  : 0.167
# ClientLoss : [0.162, 0.214, 0.742, 0.055, 2.358]
# Active     : [0, 1, 3, 4, 5]
# Delayed    : [2]
# ===========================================
#
#
# ================ ROUND 22 ================
# Acc        : 44.73%
# Precision  : 0.503
# Recall     : 0.500
# F1 Score   : 0.332
# Fairness   : 36.414
# Avg Stale  : 0.333
# ClientLoss : [0.39, 0.0, 2.953, 0.161, 5.873]
# Active     : [0, 1, 3, 4, 5]
# Delayed    : [2]
# ===========================================
#
#
# ================ ROUND 23 ================
# Acc        : 74.93%
# Precision  : 0.573
# Recall     : 0.737
# F1 Score   : 0.636
# Fairness   : 44.184
# Avg Stale  : 0.000
# ClientLoss : [0.45, 1.846, 0.218, 4.117, 0.062, 8.126]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 24 ================
# Acc        : 65.53%
# Precision  : 0.541
# Recall     : 0.664
# F1 Score   : 0.563
# Fairness   : 36.435
# Avg Stale  : 0.000
# ClientLoss : [0.291, 0.044, 0.08, 2.439, 0.085, 3.849]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 25 ================
# Acc        : 80.63%
# Precision  : 0.813
# Recall     : 0.807
# F1 Score   : 0.781
# Fairness   : 25.842
# Avg Stale  : 0.167
# ClientLoss : [0.113, 0.175, 0.061, 0.775, 0.053]
# Active     : [0, 1, 2, 3, 4]
# Delayed    : [5]
# ===========================================
#
#
# ================ ROUND 26 ================
# Acc        : 44.30%
# Precision  : 0.253
# Recall     : 0.497
# F1 Score   : 0.323
# Fairness   : 36.555
# Avg Stale  : 0.167
# ClientLoss : [0.049, 0.1, 0.066, 0.079, 0.365]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 27 ================
# Acc        : 73.79%
# Precision  : 0.568
# Recall     : 0.727
# F1 Score   : 0.627
# Fairness   : 43.415
# Avg Stale  : 0.500
# ClientLoss : [0.3, 0.539, 2.029, 4.355]
# Active     : [0, 1, 3, 5]
# Delayed    : [2, 4]
# ===========================================
#
#
# ================ ROUND 28 ================
# Acc        : 64.53%
# Precision  : 0.539
# Recall     : 0.655
# F1 Score   : 0.556
# Fairness   : 36.728
# Avg Stale  : 0.000
# ClientLoss : [0.19, 0.008, 0.054, 1.759, 0.066, 2.418]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 29 ================
# Acc        : 62.96%
# Precision  : 0.531
# Recall     : 0.644
# F1 Score   : 0.539
# Fairness   : 35.026
# Avg Stale  : 0.333
# ClientLoss : [0.108, 0.443, 0.053, 0.943]
# Active     : [0, 3, 4, 5]
# Delayed    : [1, 2]
# ===========================================
#
# QFedAvg+FedBuff finished, model saved.

# %%
# CELL 10
print("Running QFedAvg + FedBuff + FedProx | DIRICHLET_ALPHA =", DIRICHLET_ALPHA)
model = SimpleEffNet(num_classes=NUM_CLASSES).to(DEVICE)
buffer = FedBuff()
log_data = []
staleness = {cid: 0 for cid in client_map}

for r in range(ROUNDS):
    active, delayed = [], []
    for cid in client_loaders:
        if random.random() < DELAY_PROB:
            delayed.append(cid); staleness[cid] += 1
        else:
            active.append(cid); staleness[cid] = 0

    client_models, client_losses, client_samples = [], [], []
    for cid in active:
        lm, loss = local_train(model, client_loaders[cid]["train"], LOCAL_EPOCHS, use_fedprox=True, mu=0.08)
        client_models.append(lm); client_losses.append(loss)
        client_samples.append(len(client_loaders[cid]["train"].dataset))

    for cid in delayed:
        lm, loss = local_train(model, client_loaders[cid]["train"], LOCAL_EPOCHS, use_fedprox=True, mu=0.08)
        buffer.add(lm.state_dict(), len(client_loaders[cid]["train"].dataset), r)

    if len(client_models) > 0:
        q_weights = compute_q_weights(client_losses, client_samples, q=Q_VAL)
        model.load_state_dict(fedavg_aggregate(model, client_models, q_weights))

    model.load_state_dict(buffer.apply(model.state_dict(), cur_round=r, apply_prob=0.4, max_age=8, apply_mult=FEDBUFF_APPLY_MULT))

    gacc, prec, rec, f1 = evaluate(model, central_val_loader)
    accs = [evaluate(model, client_loaders[c]["val"])[0] for c in client_loaders]
    fairness = float(np.std(accs)) if len(accs) else 0.0
    avg_stale = float(np.mean(list(staleness.values()))) if len(staleness)>0 else 0.0

    stats = {"round": r, "acc": gacc, "prec": prec, "rec": rec, "f1": f1,
             "fairness": fairness, "avg_stale": avg_stale, "losses": client_losses,
             "active": active, "delayed": delayed}
    print_summary(r, stats); log_data.append(stats)

with open(f"/kaggle/working/logs/QFedAvg_FedBuff_FedProx_ALPHA_{DIRICHLET_ALPHA}.json", "w") as f: json.dump(log_data, f, indent=2)
torch.save(model.state_dict(), f"/kaggle/working/logs/QFedAvg_FedBuff_FedProx_ALPHA_{DIRICHLET_ALPHA}_final.pth")
print("QFedAvg+FedBuff+FedProx finished, model saved.")
# Out:
# Running QFedAvg + FedBuff + FedProx | DIRICHLET_ALPHA = 0.08
#
# ================ ROUND 0 ================
# Acc        : 42.88%
# Precision  : 0.221
# Recall     : 0.480
# F1 Score   : 0.300
# Fairness   : 35.701
# Avg Stale  : 0.167
# ClientLoss : [0.406, 0.616, 0.72, 0.605, 1.101]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 1 ================
# Acc        : 46.58%
# Precision  : 0.503
# Recall     : 0.513
# F1 Score   : 0.371
# Fairness   : 34.570
# Avg Stale  : 0.000
# ClientLoss : [0.387, 0.633, 0.705, 0.692, 0.667, 1.63]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 2 ================
# Acc        : 70.51%
# Precision  : 0.547
# Recall     : 0.680
# F1 Score   : 0.602
# Fairness   : 43.012
# Avg Stale  : 0.333
# ClientLoss : [0.365, 0.499, 0.626, 0.705]
# Active     : [0, 1, 3, 4]
# Delayed    : [2, 5]
# ===========================================
#
#
# ================ ROUND 3 ================
# Acc        : 65.95%
# Precision  : 0.704
# Recall     : 0.626
# F1 Score   : 0.609
# Fairness   : 34.204
# Avg Stale  : 0.167
# ClientLoss : [0.325, 0.247, 0.507, 0.52, 0.971]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 4 ================
# Acc        : 60.83%
# Precision  : 0.814
# Recall     : 0.593
# F1 Score   : 0.593
# Fairness   : 21.836
# Avg Stale  : 0.500
# ClientLoss : [0.153, 0.469, 0.374, 1.474]
# Active     : [1, 2, 3, 5]
# Delayed    : [0, 4]
# ===========================================
#
#
# ================ ROUND 5 ================
# Acc        : 78.21%
# Precision  : 0.770
# Recall     : 0.770
# F1 Score   : 0.748
# Fairness   : 27.796
# Avg Stale  : 0.167
# ClientLoss : [0.285, 0.291, 0.468, 0.114, 0.717]
# Active     : [0, 1, 2, 3, 4]
# Delayed    : [5]
# ===========================================
#
#
# ================ ROUND 6 ================
# Acc        : 72.93%
# Precision  : 0.751
# Recall     : 0.717
# F1 Score   : 0.637
# Fairness   : 40.913
# Avg Stale  : 0.000
# ClientLoss : [0.262, 0.301, 0.468, 0.318, 0.652, 1.001]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 7 ================
# Acc        : 46.58%
# Precision  : 0.489
# Recall     : 0.512
# F1 Score   : 0.358
# Fairness   : 34.730
# Avg Stale  : 0.167
# ClientLoss : [0.321, 0.348, 0.46, 0.42, 0.948]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 8 ================
# Acc        : 78.63%
# Precision  : 0.830
# Recall     : 0.791
# F1 Score   : 0.795
# Fairness   : 6.743
# Avg Stale  : 0.167
# ClientLoss : [0.769, 0.587, 0.922, 0.535, 1.959]
# Active     : [1, 2, 3, 4, 5]
# Delayed    : [0]
# ===========================================
#
#
# ================ ROUND 9 ================
# Acc        : 44.59%
# Precision  : 0.508
# Recall     : 0.497
# F1 Score   : 0.338
# Fairness   : 36.354
# Avg Stale  : 0.500
# ClientLoss : [0.48, 0.186, 0.528, 0.762]
# Active     : [1, 3, 4, 5]
# Delayed    : [0, 2]
# ===========================================
#
#
# ================ ROUND 10 ================
# Acc        : 73.36%
# Precision  : 0.544
# Recall     : 0.715
# F1 Score   : 0.617
# Fairness   : 43.149
# Avg Stale  : 0.500
# ClientLoss : [0.966, 0.524, 0.764, 0.506, 1.404]
# Active     : [1, 2, 3, 4, 5]
# Delayed    : [0]
# ===========================================
#
#
# ================ ROUND 11 ================
# Acc        : 41.17%
# Precision  : 0.800
# Recall     : 0.442
# F1 Score   : 0.402
# Fairness   : 38.341
# Avg Stale  : 0.333
# ClientLoss : [0.346, 0.265, 0.84, 1.593]
# Active     : [0, 1, 3, 5]
# Delayed    : [2, 4]
# ===========================================
#
#
# ================ ROUND 12 ================
# Acc        : 71.51%
# Precision  : 0.558
# Recall     : 0.708
# F1 Score   : 0.610
# Fairness   : 42.130
# Avg Stale  : 0.333
# ClientLoss : [0.261, 1.243, 0.155, 0.663, 0.751]
# Active     : [0, 1, 3, 4, 5]
# Delayed    : [2]
# ===========================================
#
#
# ================ ROUND 13 ================
# Acc        : 73.93%
# Precision  : 0.551
# Recall     : 0.721
# F1 Score   : 0.623
# Fairness   : 43.415
# Avg Stale  : 0.167
# ClientLoss : [0.363, 0.498, 0.842, 0.543, 1.254]
# Active     : [0, 2, 3, 4, 5]
# Delayed    : [1]
# ===========================================
#
#
# ================ ROUND 14 ================
# Acc        : 69.66%
# Precision  : 0.835
# Recall     : 0.694
# F1 Score   : 0.708
# Fairness   : 15.477
# Avg Stale  : 0.167
# ClientLoss : [0.37, 0.129, 0.477, 1.02, 1.599]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 15 ================
# Acc        : 55.27%
# Precision  : 0.536
# Recall     : 0.581
# F1 Score   : 0.482
# Fairness   : 33.101
# Avg Stale  : 0.167
# ClientLoss : [0.255, 0.59, 0.129, 0.539, 1.495]
# Active     : [0, 1, 3, 4, 5]
# Delayed    : [2]
# ===========================================
#
#
# ================ ROUND 16 ================
# Acc        : 70.37%
# Precision  : 0.797
# Recall     : 0.698
# F1 Score   : 0.602
# Fairness   : 41.370
# Avg Stale  : 0.000
# ClientLoss : [0.357, 0.905, 0.542, 0.927, 0.423, 1.392]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 17 ================
# Acc        : 73.22%
# Precision  : 0.554
# Recall     : 0.712
# F1 Score   : 0.622
# Fairness   : 43.082
# Avg Stale  : 0.000
# ClientLoss : [0.307, 0.426, 0.484, 0.521, 0.473, 1.836]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 18 ================
# Acc        : 71.37%
# Precision  : 0.545
# Recall     : 0.707
# F1 Score   : 0.605
# Fairness   : 41.549
# Avg Stale  : 0.333
# ClientLoss : [0.329, 0.732, 0.469, 1.346]
# Active     : [2, 3, 4, 5]
# Delayed    : [0, 1]
# ===========================================
#
#
# ================ ROUND 19 ================
# Acc        : 72.93%
# Precision  : 0.552
# Recall     : 0.718
# F1 Score   : 0.618
# Fairness   : 43.266
# Avg Stale  : 0.000
# ClientLoss : [0.312, 0.425, 0.45, 0.737, 0.497, 1.4]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 20 ================
# Acc        : 60.40%
# Precision  : 0.838
# Recall     : 0.589
# F1 Score   : 0.582
# Fairness   : 22.851
# Avg Stale  : 0.167
# ClientLoss : [0.287, 0.308, 0.346, 0.541, 1.955]
# Active     : [0, 1, 2, 3, 5]
# Delayed    : [4]
# ===========================================
#
#
# ================ ROUND 21 ================
# Acc        : 72.36%
# Precision  : 0.551
# Recall     : 0.714
# F1 Score   : 0.613
# Fairness   : 42.830
# Avg Stale  : 0.167
# ClientLoss : [0.206, 0.46, 0.096, 0.451, 1.592]
# Active     : [0, 2, 3, 4, 5]
# Delayed    : [1]
# ===========================================
#
#
# ================ ROUND 22 ================
# Acc        : 72.36%
# Precision  : 0.549
# Recall     : 0.714
# F1 Score   : 0.612
# Fairness   : 43.066
# Avg Stale  : 0.167
# ClientLoss : [0.293, 0.42, 0.458, 0.455, 1.886]
# Active     : [0, 1, 2, 4, 5]
# Delayed    : [3]
# ===========================================
#
#
# ================ ROUND 23 ================
# Acc        : 51.71%
# Precision  : 0.811
# Recall     : 0.535
# F1 Score   : 0.487
# Fairness   : 28.957
# Avg Stale  : 0.333
# ClientLoss : [0.276, 0.357, 0.476, 0.421, 1.696]
# Active     : [0, 1, 2, 4, 5]
# Delayed    : [3]
# ===========================================
#
#
# ================ ROUND 24 ================
# Acc        : 43.16%
# Precision  : 0.823
# Recall     : 0.436
# F1 Score   : 0.392
# Fairness   : 34.202
# Avg Stale  : 0.500
# ClientLoss : [0.229, 0.641, 0.382, 0.41, 1.632]
# Active     : [0, 1, 2, 4, 5]
# Delayed    : [3]
# ===========================================
#
#
# ================ ROUND 25 ================
# Acc        : 68.23%
# Precision  : 0.798
# Recall     : 0.658
# F1 Score   : 0.592
# Fairness   : 40.452
# Avg Stale  : 0.000
# ClientLoss : [0.239, 0.672, 0.429, 0.08, 0.41, 1.454]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 26 ================
# Acc        : 75.50%
# Precision  : 0.802
# Recall     : 0.742
# F1 Score   : 0.672
# Fairness   : 39.585
# Avg Stale  : 0.000
# ClientLoss : [0.278, 0.083, 0.414, 0.465, 0.499, 1.094]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 27 ================
# Acc        : 73.36%
# Precision  : 0.800
# Recall     : 0.723
# F1 Score   : 0.631
# Fairness   : 42.392
# Avg Stale  : 0.000
# ClientLoss : [0.235, 0.278, 0.446, 0.362, 0.434, 0.859]
# Active     : [0, 1, 2, 3, 4, 5]
# Delayed    : []
# ===========================================
#
#
# ================ ROUND 28 ================
# Acc        : 73.08%
# Precision  : 0.806
# Recall     : 0.722
# F1 Score   : 0.629
# Fairness   : 42.466
# Avg Stale  : 0.167
# ClientLoss : [0.295, 0.327, 0.356, 0.428, 0.421]
# Active     : [0, 1, 2, 3, 4]
# Delayed    : [5]
# ===========================================
#
#
# ================ ROUND 29 ================
# Acc        : 73.36%
# Precision  : 0.803
# Recall     : 0.721
# F1 Score   : 0.622
# Fairness   : 42.914
# Avg Stale  : 0.333
# ClientLoss : [0.278, 0.343, 0.444, 0.476, 0.443]
# Active     : [0, 1, 2, 3, 4]
# Delayed    : [5]
# ===========================================
#
# QFedAvg+FedBuff+FedProx finished, model saved.

# %%
# CELL 11
print("Final evaluation on central TEST set for saved models:")

paths = {
    "FedAvg": f"/kaggle/working/logs/FedAvg_alpha_{DIRICHLET_ALPHA}_final.pth",
    "FedBuff": f"/kaggle/working/logs/FedBuff_alpha_{DIRICHLET_ALPHA}_final.pth",
    "QFedAvg+FedBuff": f"/kaggle/working/logs/QFedAvg_FedBuff_ALPHA_{DIRICHLET_ALPHA}_final.pth",
    "QFedAvg+FedBuff+FedProx": f"/kaggle/working/logs/QFedAvg_FedBuff_FedProx_ALPHA_{DIRICHLET_ALPHA}_final.pth"
}

for name, p in paths.items():
    if os.path.exists(p):
        m = SimpleEffNet(num_classes=len(full_dataset.classes)).to(DEVICE)
        m.load_state_dict(torch.load(p, map_location=DEVICE))
        acc, prec, rec, f1 = evaluate(m, central_test_loader)
        print(f"{name}: TEST acc={acc:.2f}, prec={prec:.3f}, rec={rec:.3f}, f1={f1:.3f}")
    else:
        print(f"{name}: model file not found at {p}")

# Optional: zip logs for download
import shutil
shutil.make_archive("/kaggle/working/dtfl_logs", 'zip', "/kaggle/working/logs")
print("Logs & models zipped to /kaggle/working/dtfl_logs.zip (check Output files to download).")
# Out:
# Final evaluation on central TEST set for saved models:
# FedAvg: TEST acc=58.75, prec=0.525, rec=0.597, f1=0.495
# FedBuff: TEST acc=75.39, prec=0.577, rec=0.735, f1=0.637
# QFedAvg+FedBuff: TEST acc=65.86, prec=0.545, rec=0.655, f1=0.560
# QFedAvg+FedBuff+FedProx: TEST acc=74.40, prec=0.814, rec=0.725, f1=0.635
# Logs & models zipped to /kaggle/working/dtfl_logs.zip (check Output files to download).

# %%
import json
import os

BASE = "/kaggle/input/dtfl-alpha0-08"
json_files = [f for f in os.listdir(BASE) if f.endswith(".json")]

all_methods = {}

for jf in json_files:
    path = os.path.join(BASE, jf)
    try:
        with open(path, "r") as f:
            data = json.load(f)
        
        # If data is a dict with a single key pointing to list, unwrap it
        if isinstance(data, dict) and len(data)==1 and isinstance(list(data.values())[0], list):
            data = list(data.values())[0]
        
        # Now data should be a list of dicts
        if isinstance(data, list) and all(isinstance(d, dict) for d in data):
            rounds = [d.get("round") for d in data]
            acc = [d.get("acc") for d in data]
            prec = [d.get("prec") for d in data]
            rec = [d.get("rec") for d in data]
            f1 = [d.get("f1") for d in data]
            fairness = [d.get("fairness") for d in data]
            avg_stale = [d.get("avg_stale") for d in data]
            losses = [d.get("losses") for d in data]  # list of lists
            
            all_methods[jf.replace(".json","")] = {
                "rounds": rounds,
                "acc": acc,
                "prec": prec,
                "rec": rec,
                "f1": f1,
                "fairness": fairness,
                "avg_stale": avg_stale,
                "losses": losses
            }
        else:
            print("Skipping JSON (bad format):", jf)
    except Exception as e:
        print("Error loading", jf, "->", e)

print("Loaded methods:", list(all_methods.keys()))
# Out:
# Skipping JSON (bad format): client_map.json
# Loaded methods: ['FedAvg_alpha_0.08', 'QFedAvg_FedBuff_FedProx_ALPHA_0.08', 'QFedAvg_FedBuff_ALPHA_0.08', 'FedBuff_alpha_0.08']

# %%
import matplotlib.pyplot as plt
import numpy as np

for method, d in all_methods.items():
    # 1️⃣ Metrics vs Rounds
    plt.figure(figsize=(12,6))
    plt.plot(d["rounds"], d["acc"], marker='o', label="Accuracy")
    plt.plot(d["rounds"], d["f1"], marker='x', label="F1 Score")
    plt.plot(d["rounds"], d["prec"], marker='^', label="Precision")
    plt.plot(d["rounds"], d["rec"], marker='s', label="Recall")
    plt.xlabel("Round")
    plt.ylabel("Metric Value")
    plt.title(f"Metrics per Round - {method}")
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # 2️⃣ Fairness vs Round
    plt.figure(figsize=(10,4))
    plt.plot(d["rounds"], d["fairness"], marker='o', color='purple')
    plt.xlabel("Round")
    plt.ylabel("Fairness")
    plt.title(f"Fairness per Round - {method}")
    plt.grid(True)
    plt.show()
    
    # 3️⃣ Average Staleness vs Round
    plt.figure(figsize=(10,4))
    plt.plot(d["rounds"], d["avg_stale"], marker='o', color='orange')
    plt.xlabel("Round")
    plt.ylabel("Avg Staleness")
    plt.title(f"Average Staleness per Round - {method}")
    plt.grid(True)
    plt.show()
    
    # 4️⃣ Client Loss heatmap (with padding for unequal lengths)
    max_clients = max(len(cl) for cl in d["losses"])
    padded_losses = [cl + [np.nan]*(max_clients - len(cl)) for cl in d["losses"]]
    loss_matrix = np.array(padded_losses)
    
    plt.figure(figsize=(10,6))
    plt.imshow(loss_matrix, cmap='viridis', aspect='auto', interpolation='none')
    plt.colorbar(label="Client Loss")
    plt.xlabel("Client")
    plt.ylabel("Round")
    plt.title(f"Client Loss per Round - {method}")
    plt.show()

    # 5️⃣ Global Loss per Round
    avg_loss_per_round = [np.mean(cl) for cl in d["losses"]]
    plt.figure(figsize=(10,5))
    plt.plot(d["rounds"], avg_loss_per_round, marker='o', color='red')
    plt.xlabel("Round")
    plt.ylabel("Average Client Loss")
    plt.title(f"Average Loss per Round - {method}")
    plt.grid(True)
    plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/matplotlib/colors.py:721: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt

# ------------------------------
# 1. Load JSONs
# ------------------------------
BASE = "/kaggle/input/dtfl-alpha0-08"  # Change if needed
json_files = [f for f in os.listdir(BASE) if f.endswith(".json")]

all_methods = {}

for jf in json_files:
    path = os.path.join(BASE, jf)
    try:
        with open(path, "r") as f:
            data = json.load(f)
        
        if isinstance(data, dict) and len(data)==1 and isinstance(list(data.values())[0], list):
            data = list(data.values())[0]
        
        if isinstance(data, list) and all(isinstance(d, dict) for d in data):
            rounds = [d.get("round", None) for d in data]
            acc = [d.get("acc", None) for d in data]
            prec = [d.get("prec", None) for d in data]
            rec = [d.get("rec", None) for d in data]
            f1 = [d.get("f1", None) for d in data]
            fairness = [d.get("fairness", None) for d in data]
            avg_stale = [d.get("avg_stale", None) for d in data]
            losses = [d.get("losses", None) for d in data]
            
            method_name = jf.replace(".json","").upper()
            all_methods[method_name] = {
                "rounds": rounds,
                "acc": acc,
                "prec": prec,
                "rec": rec,
                "f1": f1,
                "fairness": fairness,
                "avg_stale": avg_stale,
                "losses": losses
            }
        else:
            print("Skipping JSON (bad format):", jf)
    except Exception as e:
        print("Error loading", jf, "->", e)

print("Loaded methods:", list(all_methods.keys()))

# ------------------------------
# 2. Sanity Checks
# ------------------------------
def sanity_check(metric, name, method):
    metric_np = np.array(metric)
    if np.any(metric_np < 0) or np.any(metric_np > 1):
        print(f"[WARNING] {name} out of bounds for {method}")
    print(f"{method} - {name}: min={np.nanmin(metric_np):.3f}, max={np.nanmax(metric_np):.3f}, mean={np.nanmean(metric_np):.3f}")

for method, metrics in all_methods.items():
    print(f"\n=== SANITY CHECK: {method} ===")
    for m_name in ["acc", "prec", "rec", "f1", "fairness", "avg_stale"]:
        if metrics[m_name][0] is not None:
            sanity_check(metrics[m_name], m_name, method)

# ------------------------------
# 3. Plot Metrics over Rounds
# ------------------------------
def plot_metric(metric_name, ylabel, methods=all_methods):
    plt.figure(figsize=(10,6))
    for method, metrics in methods.items():
        rounds = metrics["rounds"]
        values = metrics[metric_name]
        if values[0] is not None:
            plt.plot(rounds, values, label=method)
    plt.xlabel("Rounds")
    plt.ylabel(ylabel)
    plt.title(f"{ylabel} over Rounds")
    plt.legend()
    plt.grid(True)
    plt.show()

for m in ["acc", "prec", "rec", "f1", "fairness", "avg_stale"]:
    plot_metric(m, m.upper())

# ------------------------------
# 4. Plot Loss Curves
# ------------------------------
plt.figure(figsize=(10,6))
for method, metrics in all_methods.items():
    all_losses = metrics["losses"]
    if all_losses[0] is not None:
        # Flatten loss per round (if stored as list of client losses)
        mean_loss = [np.mean(l) if l is not None else None for l in all_losses]
        plt.plot(metrics["rounds"], mean_loss, label=method)
plt.xlabel("Rounds")
plt.ylabel("Mean Loss")
plt.title("Loss Curves over Rounds")
plt.legend()
plt.grid(True)
plt.show()

# ------------------------------
# 5. Optional: Check for Missing Values
# ------------------------------
for method, metrics in all_methods.items():
    for key, vals in metrics.items():
        if any(v is None for v in vals):
            print(f"[MISSING DATA] {method} - {key} has missing values.")
# Out:
# Skipping JSON (bad format): client_map.json
# Loaded methods: ['FEDAVG_ALPHA_0.08', 'QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08', 'QFEDAVG_FEDBUFF_ALPHA_0.08', 'FEDBUFF_ALPHA_0.08']
#
# === SANITY CHECK: FEDAVG_ALPHA_0.08 ===
# [WARNING] acc out of bounds for FEDAVG_ALPHA_0.08
# FEDAVG_ALPHA_0.08 - acc: min=43.590, max=61.396, mean=48.927
# FEDAVG_ALPHA_0.08 - prec: min=0.221, max=0.528, mean=0.433
# FEDAVG_ALPHA_0.08 - rec: min=0.489, max=0.630, mean=0.533
# FEDAVG_ALPHA_0.08 - f1: min=0.303, max=0.523, mean=0.381
# [WARNING] fairness out of bounds for FEDAVG_ALPHA_0.08
# FEDAVG_ALPHA_0.08 - fairness: min=33.288, max=36.587, mean=34.969
# FEDAVG_ALPHA_0.08 - avg_stale: min=0.000, max=0.000, mean=0.000
#
# === SANITY CHECK: QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08 ===
# [WARNING] acc out of bounds for QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08
# QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08 - acc: min=41.168, max=78.632, mean=64.801
# QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08 - prec: min=0.221, max=0.838, mean=0.666
# QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08 - rec: min=0.436, max=0.791, mean=0.648
# QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08 - f1: min=0.300, max=0.795, mean=0.569
# [WARNING] fairness out of bounds for QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08
# QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08 - fairness: min=6.743, max=43.415, mean=36.015
# QFEDAVG_FEDBUFF_FEDPROX_ALPHA_0.08 - avg_stale: min=0.000, max=0.500, mean=0.200
#
# === SANITY CHECK: QFEDAVG_FEDBUFF_ALPHA_0.08 ===
# [WARNING] acc out of bounds for QFEDAVG_FEDBUFF_ALPHA_0.08
# QFEDAVG_FEDBUFF_ALPHA_0.08 - acc: min=37.037, max=80.627, mean=55.494
# QFEDAVG_FEDBUFF_ALPHA_0.08 - prec: min=0.225, max=0.813, mean=0.463
# QFEDAVG_FEDBUFF_ALPHA_0.08 - rec: min=0.312, max=0.807, mean=0.575
# QFEDAVG_FEDBUFF_ALPHA_0.08 - f1: min=0.228, max=0.781, mean=0.457
# [WARNING] fairness out of bounds for QFEDAVG_FEDBUFF_ALPHA_0.08
# QFEDAVG_FEDBUFF_ALPHA_0.08 - fairness: min=19.490, max=44.184, mean=36.048
# QFEDAVG_FEDBUFF_ALPHA_0.08 - avg_stale: min=0.000, max=0.500, mean=0.156
#
# === SANITY CHECK: FEDBUFF_ALPHA_0.08 ===
# [WARNING] acc out of bounds for FEDBUFF_ALPHA_0.08
# FEDBUFF_ALPHA_0.08 - acc: min=23.504, max=75.641, mean=55.750
# FEDBUFF_ALPHA_0.08 - prec: min=0.059, max=0.825, mean=0.559
# FEDBUFF_ALPHA_0.08 - rec: min=0.250, max=0.741, mean=0.572
# FEDBUFF_ALPHA_0.08 - f1: min=0.095, max=0.715, mean=0.461
# [WARNING] fairness out of bounds for FEDBUFF_ALPHA_0.08
# FEDBUFF_ALPHA_0.08 - fairness: min=7.207, max=44.508, mean=34.947
# FEDBUFF_ALPHA_0.08 - avg_stale: min=0.000, max=1.000, mean=0.367

# %%
import matplotlib.pyplot as plt
import numpy as np

# ------------------------------
# Combined Dashboard per Method
# ------------------------------
for method, metrics in all_methods.items():
    rounds = metrics["rounds"]

    # Prepare loss (mean per round if list of client losses)
    losses = metrics["losses"]
    mean_loss = [np.mean(l) if l is not None else None for l in losses]

    fig, axs = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle(f"Performance Dashboard - {method}", fontsize=16)

    # Accuracy
    axs[0,0].plot(rounds, metrics["acc"], marker='o')
    axs[0,0].set_title("Accuracy")
    axs[0,0].set_xlabel("Rounds")
    axs[0,0].set_ylabel("Accuracy")
    axs[0,0].grid(True)

    # Precision
    axs[0,1].plot(rounds, metrics["prec"], marker='o', color='orange')
    axs[0,1].set_title("Precision")
    axs[0,1].set_xlabel("Rounds")
    axs[0,1].set_ylabel("Precision")
    axs[0,1].grid(True)

    # Recall
    axs[0,2].plot(rounds, metrics["rec"], marker='o', color='green')
    axs[0,2].set_title("Recall")
    axs[0,2].set_xlabel("Rounds")
    axs[0,2].set_ylabel("Recall")
    axs[0,2].grid(True)

    # F1 Score
    axs[1,0].plot(rounds, metrics["f1"], marker='o', color='red')
    axs[1,0].set_title("F1 Score")
    axs[1,0].set_xlabel("Rounds")
    axs[1,0].set_ylabel("F1")
    axs[1,0].grid(True)

    # Fairness
    axs[1,1].plot(rounds, metrics["fairness"], marker='o', color='purple')
    axs[1,1].set_title("Fairness")
    axs[1,1].set_xlabel("Rounds")
    axs[1,1].set_ylabel("Fairness")
    axs[1,1].grid(True)

    # Loss
    axs[1,2].plot(rounds, mean_loss, marker='o', color='brown')
    axs[1,2].set_title("Mean Loss")
    axs[1,2].set_xlabel("Rounds")
    axs[1,2].set_ylabel("Loss")
    axs[1,2].grid(True)

    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()
